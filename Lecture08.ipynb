# %% [markdown]
# In this notebook, we cover:
#
# * [Typical and Unusual Values](#Typical-and-Unusual-Values)
# * [Missing Values](#Missing-Values)

# %% [markdown]
# # Typical and Unusual Values

# %%
library(tidyverse)
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats

# %%
print(diamonds)
# Out:
# # A tibble: 53,940 x 10
#    carat       cut color clarity depth table price     x     y     z
#    <dbl>     <ord> <ord>   <ord> <dbl> <dbl> <int> <dbl> <dbl> <dbl>
#  1  0.23     Ideal     E     SI2  61.5    55   326  3.95  3.98  2.43
#  2  0.21   Premium     E     SI1  59.8    61   326  3.89  3.84  2.31
#  3  0.23      Good     E     VS1  56.9    65   327  4.05  4.07  2.31
#  4  0.29   Premium     I     VS2  62.4    58   334  4.20  4.23  2.63
#  5  0.31      Good     J     SI2  63.3    58   335  4.34  4.35  2.75
#  6  0.24 Very Good     J    VVS2  62.8    57   336  3.94  3.96  2.48
#  7  0.24 Very Good     I    VVS1  62.3    57   336  3.95  3.98  2.47
#  8  0.26 Very Good     H     SI1  61.9    55   337  4.07  4.11  2.53
#  9  0.22      Fair     E     VS2  65.1    61   337  3.87  3.78  2.49
# 10  0.23 Very Good     H     VS1  59.4    61   338  4.00  4.05  2.39
# # ... with 53,930 more rows

# %%
ggplot(data = diamonds) +
    geom_histogram(mapping = aes(x = x), binwidth = 0.2)
# Out:
# plot without title

# %%
filter(diamonds, x < 1 | x > 10) %>%
    arrange(x)
# Out:
#    carat cut       color clarity depth table price x     y     z
# 1  1.07  Ideal     F     SI2     61.6  56     4954  0.00  6.62 0.00
# 2  1.00  Very Good H     VS2     63.3  53     5139  0.00  0.00 0.00
# 3  1.14  Fair      G     VS1     57.5  67     6381  0.00  0.00 0.00
# 4  1.56  Ideal     G     VS2     62.2  54    12800  0.00  0.00 0.00
# 5  1.20  Premium   D     VVS1    62.1  59    15686  0.00  0.00 0.00
# 6  2.25  Premium   H     SI2     62.8  59    18034  0.00  0.00 0.00
# 7  0.71  Good      F     SI2     64.1  60     2130  0.00  0.00 0.00
# 8  0.71  Good      F     SI2     64.1  60     2130  0.00  0.00 0.00
# 9  4.00  Very Good I     I1      63.3  58    15984 10.01  9.94 6.31
# 10 4.01  Premium   J     I1      62.5  62    15223 10.02  9.94 6.24
# 11 4.01  Premium   I     I1      61.0  61    15223 10.14 10.10 6.17
# 12 4.50  Fair      J     I1      65.8  58    18531 10.23 10.16 6.72
# 13 5.01  Fair      J     I1      65.5  59    18018 10.74 10.54 6.98

# %%
filter(diamonds, x >= 1, x <= 10) %>%
    ggplot() +
        geom_histogram(mapping = aes(x = x), binwidth = 0.2)
# Out:
# plot without title

# %%
ggplot(data = diamonds) +
    geom_histogram(mapping = aes(x = y), binwidth = 0.2)
# Out:
# plot without title

# %%
filter(diamonds, y < 1 | y > 20) %>%
    arrange(y)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 1.00  Very Good H     VS2     63.3  53     5139 0.00  0.0 0.00
# 2 1.14  Fair      G     VS1     57.5  67     6381 0.00  0.0 0.00
# 3 1.56  Ideal     G     VS2     62.2  54    12800 0.00  0.0 0.00
# 4 1.20  Premium   D     VVS1    62.1  59    15686 0.00  0.0 0.00
# 5 2.25  Premium   H     SI2     62.8  59    18034 0.00  0.0 0.00
# 6 0.71  Good      F     SI2     64.1  60     2130 0.00  0.0 0.00
# 7 0.71  Good      F     SI2     64.1  60     2130 0.00  0.0 0.00
# 8 0.51  Ideal     E     VS1     61.8  55     2075 5.15 31.8 5.12
# 9 2.00  Premium   H     SI2     58.9  57    12210 8.09 58.9 8.06

# %%
filter(diamonds, y >=1, y <= 20) %>%
    ggplot() +
        geom_histogram(mapping = aes(x = y), binwidth = 0.2)
# Out:
# plot without title

# %%
ggplot(data = diamonds) +
    geom_histogram(mapping = aes(x = z), binwidth = 0.2)
# Out:
# plot without title

# %%
filter(diamonds, z < 1 | z > 10) %>%
    arrange(z)
# Out:
#    carat cut       color clarity depth table price x    y    z
# 1  1.00  Premium   G     SI2     59.1  59.0   3142 6.55 6.48  0.0
# 2  1.01  Premium   H     I1      58.1  59.0   3167 6.66 6.60  0.0
# 3  1.10  Premium   G     SI2     63.0  59.0   3696 6.50 6.47  0.0
# 4  1.01  Premium   F     SI2     59.2  58.0   3837 6.50 6.47  0.0
# 5  1.50  Good      G     I1      64.0  61.0   4731 7.15 7.04  0.0
# 6  1.07  Ideal     F     SI2     61.6  56.0   4954 0.00 6.62  0.0
# 7  1.00  Very Good H     VS2     63.3  53.0   5139 0.00 0.00  0.0
# 8  1.15  Ideal     G     VS2     59.2  56.0   5564 6.88 6.83  0.0
# 9  1.14  Fair      G     VS1     57.5  67.0   6381 0.00 0.00  0.0
# 10 2.18  Premium   H     SI2     59.4  61.0  12631 8.49 8.45  0.0
# 11 1.56  Ideal     G     VS2     62.2  54.0  12800 0.00 0.00  0.0
# 12 2.25  Premium   I     SI1     61.3  58.0  15397 8.52 8.42  0.0
# 13 1.20  Premium   D     VVS1    62.1  59.0  15686 0.00 0.00  0.0
# 14 2.20  Premium   H     SI1     61.2  59.0  17265 8.42 8.37  0.0
# 15 2.25  Premium   H     SI2     62.8  59.0  18034 0.00 0.00  0.0
# 16 2.02  Premium   H     VS2     62.7  53.0  18207 8.02 7.95  0.0
# 17 2.80  Good      G     SI2     63.8  58.0  18788 8.90 8.85  0.0
# 18 0.71  Good      F     SI2     64.1  60.0   2130 0.00 0.00  0.0
# 19 0.71  Good      F     SI2     64.1  60.0   2130 0.00 0.00  0.0
# 20 1.12  Premium   G     I1      60.4  59.0   2383 6.71 6.67  0.0
# 21 0.51  Very Good E     VS1     61.8  54.7   1970 5.12 5.15 31.8

# %%
filter(diamonds, z >= 1, z <= 10) %>%
    ggplot() +
        geom_histogram(mapping = aes(x = z), binwidth = 0.2)
# Out:
# plot without title

# %%
summarize(diamonds, max = max(price), min = min(price))
# Out:
#   max   min
# 1 18823 326

# %%
ggplot(data = diamonds) +
    geom_histogram(mapping = aes(x = price), binwidth = 1000)
# Out:
# plot without title

# %%
ggplot(data = diamonds) +
    geom_histogram(mapping = aes(x = price), binwidth = 100)
# Out:
# plot without title

# %%
filter(diamonds, price <= 2500) %>%
    ggplot() +
    geom_histogram(mapping = aes(x = price), binwidth = 100)
# Out:
# plot without title

# %%
filter(diamonds, price <= 2500) %>%
    ggplot() +
        geom_histogram(mapping = aes(x = price), binwidth = 50)
# Out:
# plot without title

# %%
filter(diamonds, price > 1450, price < 1550)
# Out:
#    carat cut       color clarity depth table price x    y    z
# 1  0.50  Ideal     E     VS2     62.7  55.0  1451  5.08 5.12 3.20
# 2  0.52  Ideal     F     VS2     61.3  56.0  1451  5.14 5.20 3.17
# 3  0.52  Premium   F     VS2     60.2  59.0  1451  5.19 5.21 3.13
# 4  0.50  Very Good E     VS2     62.1  62.0  1451  5.08 5.10 3.16
# 5  0.46  Very Good E     VS1     58.7  60.0  1452  5.08 5.15 3.00
# 6  0.52  Very Good D     SI1     63.8  56.0  1452  5.06 5.10 3.24
# 7  0.59  Very Good F     SI1     62.4  59.0  1452  5.33 5.37 3.34
# 8  0.54  Ideal     I     VS1     62.3  57.0  1452  5.20 5.24 3.25
# 9  0.58  Very Good E     SI1     59.6  57.0  1453  5.41 5.42 3.23
# 10 0.46  Ideal     G     VVS1    60.7  57.0  1453  4.98 5.03 3.04
# 11 0.54  Ideal     H     VS2     61.6  55.0  1453  5.23 5.25 3.23
# 12 0.54  Ideal     H     VS2     61.5  55.0  1453  5.25 5.28 3.24
# 13 0.54  Ideal     I     VS1     63.1  55.0  1453  5.18 5.22 3.27
# 14 0.50  Very Good D     SI1     61.6  56.0  1454  5.09 5.11 3.14
# 15 0.52  Ideal     I     VVS1    60.1  56.0  1454  5.24 5.27 3.16
# 16 0.54  Ideal     H     VS1     61.2  55.0  1454  5.25 5.31 3.23
# 17 0.51  Premium   G     VS2     61.2  60.0  1546  5.17 5.12 3.15
# 18 0.51  Ideal     G     VS2     62.9  54.0  1546  5.12 5.08 3.21
# 19 0.51  Premium   G     VS2     62.4  57.0  1546  5.11 5.09 3.18
# 20 0.51  Premium   G     VS2     62.7  58.0  1546  5.12 5.09 3.20
# 21 0.51  Premium   G     VS2     62.2  57.0  1546  5.15 5.10 3.19
# 22 0.51  Ideal     G     VS2     62.7  57.0  1546  5.12 5.05 3.19
# 23 0.51  Premium   G     VS2     62.9  58.0  1546  5.11 5.06 3.20
# 24 0.51  Premium   G     VS2     62.3  59.0  1546  5.10 5.07 3.17
# 25 0.51  Ideal     E     SI1     59.6  57.0  1546  5.24 5.20 3.11
# 26 0.51  Premium   E     SI1     61.3  54.0  1546  5.18 5.13 3.16
# 27 0.51  Ideal     E     SI1     61.5  55.0  1546  5.18 5.16 3.18
# 28 0.51  Premium   E     SI1     60.8  57.0  1546  5.24 5.19 3.17
# 29 0.51  Ideal     E     SI1     62.8  56.0  1546  5.15 5.07 3.21
# 30 0.51  Ideal     E     SI1     62.2  57.0  1546  5.12 5.08 3.17
# 31 0.51  Ideal     E     SI1     62.1  55.0  1546  5.15 5.09 3.18
# 32 0.51  Ideal     E     SI1     61.3  55.0  1546  5.17 5.11 3.15
# 33 0.51  Premium   E     SI1     62.5  57.0  1546  5.09 5.06 3.17
# 34 0.51  Ideal     E     SI1     62.7  55.0  1546  5.10 5.07 3.19
# 35 0.51  Ideal     E     SI1     62.8  55.0  1546  5.12 5.07 3.20
# 36 0.51  Premium   E     SI1     62.3  58.0  1546  5.12 5.05 3.17
# 37 0.51  Premium   G     VS2     62.4  58.0  1546  5.12 5.11 3.19
# 38 0.50  Very Good E     VS2     61.8  57.0  1547  5.05 5.11 3.14
# 39 0.72  Good      J     SI1     60.1  64.0  1547  5.75 5.83 3.48
# 40 0.42  Ideal     D     VVS1    61.8  55.0  1547  4.83 4.85 2.99
# 41 0.42  Ideal     D     VVS1    61.6  56.0  1547  4.79 4.82 2.96
# 42 0.42  Very Good D     VVS1    62.8  56.0  1547  4.76 4.80 3.00
# 43 0.42  Ideal     D     VVS1    61.8  56.0  1547  4.79 4.82 2.97
# 44 0.61  Premium   F     SI1     62.4  59.0  1547  5.37 5.33 3.34
# 45 0.52  Ideal     D     SI1     61.1  57.0  1547  5.19 5.25 3.19
# 46 0.97  Fair      G     I1      57.2  60.0  1547  6.59 6.36 3.72
# 47 0.53  Very Good H     VVS2    61.3  61.0  1548  5.15 5.20 3.17
# 48 0.55  Very Good H     VS2     62.0  55.2  1548  5.28 5.31 3.28
# 49 0.51  Ideal     D     SI1     62.4  57.0  1548  5.11 5.15 3.20
# 50 0.61  Very Good G     SI1     59.7  63.0  1548  5.50 5.43 3.26
# 51 0.45  Ideal     G     IF      61.7  55.0  1548  4.93 4.96 3.05
# 52 0.45  Good      F     VVS1    63.8  58.0  1548  4.85 4.78 3.07
# 53 0.45  Premium   D     VVS2    59.8  59.0  1548  5.01 4.85 2.96
# 54 0.51  Very Good E     VS2     64.1  57.0  1549  5.02 5.06 3.23
# 55 0.51  Very Good E     VS2     60.0  57.0  1549  5.15 5.19 3.10
# 56 0.51  Good      D     VS2     63.7  57.0  1549  5.00 5.05 3.20
# 57 0.52  Ideal     G     VS2     61.9  55.0  1549  5.15 5.18 3.20
# 58 0.52  Ideal     E     VS2     62.3  53.0  1549  5.17 5.20 3.23
# 59 0.53  Ideal     G     SI1     61.1  55.0  1549  5.24 5.26 3.21

# %%
ggplot(data = diamonds) +
    geom_histogram(mapping = aes(x = price), binwidth = 1000) +
    facet_wrap(~ cut)
# Out:
# plot without title

# %%
ggplot(data = diamonds) +
    geom_histogram(mapping = aes(x = carat), binwidth = 0.1)
# Out:
# plot without title

# %%
filter(diamonds, carat > 3) %>%
    arrange(carat)
# Out:
#    carat cut       color clarity depth table price x     y     z
# 1  3.01  Premium   I     I1      62.7  58     8040  9.10  8.97 5.67
# 2  3.01  Premium   F     I1      62.2  56     9925  9.24  9.13 5.73
# 3  3.01  Fair      H     I1      56.1  62    10761  9.54  9.38 5.31
# 4  3.01  Premium   G     SI2     59.8  58    14220  9.44  9.37 5.62
# 5  3.01  Ideal     J     SI2     61.7  58    16037  9.25  9.20 5.69
# 6  3.01  Ideal     J     I1      65.4  60    16538  8.99  8.93 5.86
# 7  3.01  Premium   I     SI2     60.2  59    18242  9.36  9.31 5.62
# 8  3.01  Fair      I     SI2     65.8  56    18242  8.99  8.94 5.90
# 9  3.01  Fair      I     SI2     65.8  56    18242  8.99  8.94 5.90
# 10 3.01  Good      I     SI2     63.9  60    18242  9.06  9.01 5.77
# 11 3.01  Good      I     SI2     63.9  60    18242  9.06  9.01 5.77
# 12 3.01  Good      H     SI2     57.6  64    18593  9.44  9.38 5.42
# 13 3.01  Premium   J     SI2     60.7  59    18710  9.35  9.22 5.64
# 14 3.01  Premium   J     SI2     59.7  58    18710  9.41  9.32 5.59
# 15 3.02  Fair      I     I1      65.2  56    10577  9.11  9.02 5.91
# 16 3.04  Very Good I     SI2     63.2  59    15354  9.14  9.07 5.75
# 17 3.04  Premium   I     SI2     59.3  60    18559  9.51  9.46 5.62
# 18 3.05  Premium   E     I1      60.9  58    10453  9.26  9.25 5.66
# 19 3.11  Fair      J     I1      65.9  57     9823  9.15  9.02 5.98
# 20 3.22  Ideal     I     I1      62.6  55    12545  9.49  9.42 5.92
# 21 3.24  Premium   H     I1      62.1  58    12300  9.44  9.40 5.85
# 22 3.40  Fair      D     I1      66.8  52    15964  9.42  9.34 6.27
# 23 3.50  Ideal     H     I1      62.8  57    12587  9.65  9.59 6.03
# 24 3.51  Premium   J     VS2     62.5  59    18701  9.66  9.63 6.03
# 25 3.65  Fair      H     I1      67.1  53    11668  9.53  9.48 6.38
# 26 3.67  Premium   I     I1      62.4  56    16193  9.86  9.81 6.13
# 27 4.00  Very Good I     I1      63.3  58    15984 10.01  9.94 6.31
# 28 4.01  Premium   I     I1      61.0  61    15223 10.14 10.10 6.17
# 29 4.01  Premium   J     I1      62.5  62    15223 10.02  9.94 6.24
# 30 4.13  Fair      H     I1      64.8  61    17329 10.00  9.85 6.43
# 31 4.50  Fair      J     I1      65.8  58    18531 10.23 10.16 6.72
# 32 5.01  Fair      J     I1      65.5  59    18018 10.74 10.54 6.98

# %%
filter(diamonds, carat > 0.5, carat < 1.5) %>%
    ggplot() +
        geom_histogram(mapping = aes(x = carat), binwidth = 0.01)
# Out:
# plot without title

# %% [markdown]
# # Missing Values

# %%
filter(diamonds, near(x,0) | near(y,0) | near(z, 0))
# Out:
#    carat cut       color clarity depth table price x    y    z
# 1  1.00  Premium   G     SI2     59.1  59     3142 6.55 6.48 0
# 2  1.01  Premium   H     I1      58.1  59     3167 6.66 6.60 0
# 3  1.10  Premium   G     SI2     63.0  59     3696 6.50 6.47 0
# 4  1.01  Premium   F     SI2     59.2  58     3837 6.50 6.47 0
# 5  1.50  Good      G     I1      64.0  61     4731 7.15 7.04 0
# 6  1.07  Ideal     F     SI2     61.6  56     4954 0.00 6.62 0
# 7  1.00  Very Good H     VS2     63.3  53     5139 0.00 0.00 0
# 8  1.15  Ideal     G     VS2     59.2  56     5564 6.88 6.83 0
# 9  1.14  Fair      G     VS1     57.5  67     6381 0.00 0.00 0
# 10 2.18  Premium   H     SI2     59.4  61    12631 8.49 8.45 0
# 11 1.56  Ideal     G     VS2     62.2  54    12800 0.00 0.00 0
# 12 2.25  Premium   I     SI1     61.3  58    15397 8.52 8.42 0
# 13 1.20  Premium   D     VVS1    62.1  59    15686 0.00 0.00 0
# 14 2.20  Premium   H     SI1     61.2  59    17265 8.42 8.37 0
# 15 2.25  Premium   H     SI2     62.8  59    18034 0.00 0.00 0
# 16 2.02  Premium   H     VS2     62.7  53    18207 8.02 7.95 0
# 17 2.80  Good      G     SI2     63.8  58    18788 8.90 8.85 0
# 18 0.71  Good      F     SI2     64.1  60     2130 0.00 0.00 0
# 19 0.71  Good      F     SI2     64.1  60     2130 0.00 0.00 0
# 20 1.12  Premium   G     I1      60.4  59     2383 6.71 6.67 0

# %%
diamonds_new <- diamonds %>%
                    mutate(x = ifelse(near(x, 0) | x > 10, NA, x)) %>%
                    mutate(y = ifelse(near(y, 0) | y > 20, NA, y)) %>%
                    mutate(z = ifelse(near(z, 0) | z > 10, NA, z))

# %%
ggplot(data = diamonds_new) +
    geom_point(mapping = aes(x = x, y = y))
# Out:
# Warning message:
# “Removed 15 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(data = diamonds_new) +
    geom_point(mapping = aes(x = x, y = y), na.rm = TRUE)
# Out:
# plot without title
